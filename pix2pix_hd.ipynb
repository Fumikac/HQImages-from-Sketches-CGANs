# %% [markdown]
# This is the colab notebook I made for running [pix2pix_HD](https://github.com/NVIDIA/pix2pixHD)

# %% [markdown]
# # Install

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed Apr 21 23:10:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/CVProject-cGAN')

# %%
# !pip install dominate

# %%
#!git clone https://github.com/NVIDIA/pix2pixHD
# Out:
# Cloning into 'pix2pixHD'...
# remote: Enumerating objects: 340, done.
# remote: Total 340 (delta 0), reused 0 (delta 0), pack-reused 340
# Receiving objects: 100% (340/340), 55.68 MiB | 15.22 MiB/s, done.
# Resolving deltas: 100% (156/156), done.
# Checking out files: 100% (115/115), done.

# %%
os.chdir('pix2pixHD/')

# %% [markdown]
# # Datasets

# %% [markdown]
# Training set folders
# - 'datasets/draw2img/train_A'
# - 'datasets/draw2img/train_B'
#
# Names of files have to be labeled incremently, i.e., 0, 1, 2, .... N-1.
# If you name differently, the code will rename them, but it gives error after one iteration of training (indexing error).

# %%
# !python train.py --name draw2face_PsCannySimple --label_nc 0 --no_instance --dataroot ./datasets/draw2face_PsCannySimple
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: False
# data_type: 32
# dataroot: ./datasets/draw2face_PsCannySimple
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 0
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# local_rank: 0
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: draw2face_PsCannySimple
# ndf: 64
# nef: 16
# netG: global
# ngf: 64
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: True
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# ...

# %% [markdown]
# trained model at : ./checkpoints/draw2face_PsCannySimple

# %%
# !python test.py --dataroot ./datasets/draw2face_PsCannySimple --name draw2face_PsCannySimple --netG global --resize_or_crop none --label_nc 0 --no_instance --which_epoch 30
# Out:
# ------------ Options -------------
# aspect_ratio: 1.0
# batchSize: 1
# checkpoints_dir: ./checkpoints
# cluster_path: features_clustered_010.npy
# data_type: 32
# dataroot: ./datasets/draw2face_PsCannySimple
# display_winsize: 512
# engine: None
# export_onnx: None
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# how_many: 50
# input_nc: 3
# instance_feat: False
# isTrain: False
# label_feat: False
# label_nc: 0
# loadSize: 1024
# load_features: False
# local_rank: 0
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_local_enhancers: 1
# name: draw2face_PsCannySimple
# nef: 16
# netG: global
# ngf: 64
# niter_fix_global: 0
# no_flip: False
# no_instance: True
# norm: instance
# ntest: inf
# onnx: None
# output_nc: 3
# phase: test
# resize_or_crop: none
# results_dir: ./results/
# serial_batches: False
# tf_log: False
# use_dropout: False
# ...

# %% [markdown]
# Results saved at ./results/
